# %% [markdown]
# ## Discussion of Results

# %% [markdown]
# ### Project Descripton

# %% [markdown]
# Questions to answer:
# 1. What are the most common words used in inaugural addresses?
#     - How has this changed over time?
# 2. How has the tone of inaugural addresses changed over time?
#     - Has there been more fearmongering or polarizing speech over time?
#     - Which president has the most polarizing speech?
#     - along party lines, which party has the most polarizing speech?
# 3. What are the most common themes in inaugural addresses?
#     - How has this changed over time?
#     - Does a certain party have more polarizing speech?
# 4. Second vs first term inaugural addresses
#     - Are there any differences between the two? (length, tone, themes, etc.)

# %% [markdown]
# ## Author Contributions
# - Calvin:
# - Clara:
# - Halasya:
# - Navein:
